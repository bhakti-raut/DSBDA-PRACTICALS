# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=sns.load_dataset('tips')

# %%
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
xyz=data[['total_bill','tip','size']]

# %%
xyz.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# Heatmap
sns.heatmap(xyz.corr())
# Out:
# <Axes: >

# %%
xyz['tip']
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
#Distribution plot
# 1.Displot
sns.displot(xyz['tip'])
# Out:
# C:\Users\Bhakti\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# 2.Joinplot
sns.jointplot(x = data['tip'], y = data['total_bill'], kind =
'scatter')

# %%
# 2.Joinplot
sns.jointplot(x = data['tip'], y = data['total_bill'], kind = 'hex')

# %%
# pairplot
sns.pairplot(data)
# Out:
# C:\Users\Bhakti\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# pairplot
sns.pairplot(data, hue='sex')
# Out:
# C:\Users\Bhakti\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# 3.Rugplot
sns.rugplot(data['tip'])
# Out:
# <Axes: xlabel='tip'>

# %%
# Ctegorical Plots
# 1.Barplot
sns.barplot(x='sex', y='tip', data=data)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
#1.Barplot
sns.barplot(x='sex', y='tip', data=data, estimator=np.std)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
#2.Countplot
sns.countplot(x='sex', data=data)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
#4.Boxplot
sns.boxplot(x='sex', y='tip', data=data)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
#4.Boxplot
sns.boxplot(x='sex', y='tip', data=data, hue="smoker")
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
#5.Violinplot
sns.violinplot(x='sex', y='tip', data=data)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
# 5.Violinplot
sns.violinplot(x='sex', y='tip', data=data, hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
# 3.Advanced Plots
# 1.Stripplot
sns.stripplot(x='sex', y='tip', data=data, jitter=False)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
# 1.Stripplot
sns.stripplot(x='sex', y='tip', data=data, jitter=True, hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
# 1.Stripplot
sns.stripplot(x='sex', y='tip', data=data, jitter=True)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
#2.Swarmplot
sns.swarmplot(x='sex', y='tip', data=data)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
# 2.Swarmplot
sns.swarmplot(x='sex', y='tip', data=data, hue='smoker')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
# 4.MatrixPlots
# 1.heatmap
corr = xyz.corr()
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
# 1.heatmap
corr = xyz.corr()
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
#2.Clusterplot
sns.histplot(data['tip'], kde=False, bins=10)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>
